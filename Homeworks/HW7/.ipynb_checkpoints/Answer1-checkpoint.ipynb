# %%
import torch
from torchvision.transforms import ToTensor
from torch.utils.data import DataLoader, Subset
from torchvision import datasets
import torch.nn as nn
import matplotlib.pyplot as plt

# %%
usps_train = datasets.USPS(root="./data", train=True, transform=ToTensor(), download=True)

# %%
device = 'cuda'

# %%
class_indices = {i: [] for i in range(10)}
for idx, (_, label) in enumerate(usps_train):
    if len(class_indices[label]) < 500:
        class_indices[label].append(idx)

# Collect indices for the final dataset
final_indices = []
for indices in class_indices.values():
    final_indices.extend(indices)

# Subset the dataset
train_dataset = Subset(usps_train, final_indices)

# DataLoader
train_loader = DataLoader(train_dataset, batch_size=500, shuffle=True)

print(f"Number of samples in training dataset: {len(train_dataset)}")
# Out:
# Number of samples in training dataset: 5000

# %%
class Generator(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(10, 128),      # Input: 10, Hidden: 128
            nn.Tanh(),
            nn.Linear(128, 16 * 16), 
            nn.Tanh()
        )

    def forward(self, x):
        return self.model(x)
        
class Discriminator(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(16 * 16, 128), # Input: 16x16 grayscale image
            nn.Tanh(),
            nn.Linear(128, 1),      
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.model(x)

# %%
G = Generator().to(device)
D = Discriminator().to(device)
loss_fn = nn.BCELoss()
lr = 0.15
optimizerG = torch.optim.SGD(G.parameters(), lr=lr)
optimizerD = torch.optim.SGD(D.parameters(), lr=lr)
epochs = 300

# %%
CE_D = torch.zeros(epochs).to(device)
CE_G = torch.zeros(epochs).to(device)

flatten = nn.Flatten()

for epoch in range(epochs):
    for X, _ in train_loader:
        # Loss accumulation for real images
        D.zero_grad()
        X_real = flatten(X).to(device)  
        Y_real = torch.ones(X_real.size(0), 1).to(device)  
        outD = D(X_real)
        loss_real = loss_fn(outD, Y_real)

        # Loss accumulation for fake images
        z = torch.randn(X_real.size(0), 10).to(device)  
        X_fake = G(z)
        Y_fake = torch.zeros(X_fake.size(0), 1).to(device)  
        outD = D(X_fake)
        loss_fake = loss_fn(outD, Y_fake)

        # Gradient descent part for Discriminator
        lossD = loss_real + loss_fake
        lossD.backward()
        optimizerD.step()

        # Training the Generator
        G.zero_grad()
        z = torch.randn(X_real.size(0), 10).to(device)
        Y = torch.ones(X_fake.size(0), 1).to(device)  
        outG = G(z)
        outD = D(outG)
        lossG = loss_fn(outD, Y)
        lossG.backward()
        optimizerG.step()

    # Track losses
    CE_D[epoch] = lossD.item()
    CE_G[epoch] = lossG.item()

    # Print progress
    if (epoch + 1) % 10 == 0:
        print(f"Epoch [{epoch + 1}/{epochs}] | Loss D: {lossD.item():.4f} | Loss G: {lossG.item():.4f}")
# Out:
# Epoch [10/300] | Loss D: 1.3370 | Loss G: 0.8090
# Epoch [20/300] | Loss D: 1.3923 | Loss G: 0.7336
# Epoch [30/300] | Loss D: 1.3329 | Loss G: 0.7164
# Epoch [40/300] | Loss D: 1.3960 | Loss G: 0.5441
# Epoch [50/300] | Loss D: 1.2336 | Loss G: 0.6878
# Epoch [60/300] | Loss D: 1.1446 | Loss G: 0.7427
# Epoch [70/300] | Loss D: 1.1800 | Loss G: 0.7018
# Epoch [80/300] | Loss D: 1.1900 | Loss G: 0.7050
# Epoch [90/300] | Loss D: 1.3383 | Loss G: 0.6007
# Epoch [100/300] | Loss D: 1.2140 | Loss G: 0.6963
# Epoch [110/300] | Loss D: 1.1847 | Loss G: 0.7433
# Epoch [120/300] | Loss D: 1.1728 | Loss G: 0.8004
# Epoch [130/300] | Loss D: 1.1681 | Loss G: 1.1427
# Epoch [140/300] | Loss D: 1.1711 | Loss G: 0.9932
# Epoch [150/300] | Loss D: 1.2447 | Loss G: 1.1507
# Epoch [160/300] | Loss D: 1.2629 | Loss G: 1.3059
# Epoch [170/300] | Loss D: 1.2781 | Loss G: 0.6888
# Epoch [180/300] | Loss D: 1.2125 | Loss G: 0.8052
# Epoch [190/300] | Loss D: 1.3030 | Loss G: 0.6764
# ...

# %%
# Move losses to CPU and convert to NumPy for plotting
plt.figure(figsize=(10, 5))  
plt.plot(CE_D.cpu().numpy(), label="Discriminator Loss")  
plt.plot(CE_G.cpu().numpy(), label="Generator Loss")  
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.title("Losses Over Training")
plt.show()

# %%
generated = G(torch.randn(10, 10).to(device))  
generated = generated.view(10, 16, 16)  

plt.figure(figsize=(15, 3))  # Adjusted figure size for better visualization
for i in range(10):
    plt.subplot(1, 10, i + 1)
    plt.imshow(generated[i].cpu().detach().numpy(), cmap="gray")
    plt.axis("off")  # Turn off axis for cleaner display
plt.tight_layout()
plt.show()
